# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGuerrero1/Proyecto_EIII/blob/main/PlotRelational2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
dtt = pd.read_csv("/content/aaplMerged.csv")

# %%
dtt.set_index("Date")
fig = plt.figure()
x1 = fig.add_subplot(111)
dtt["Polarity"].plot(ax=x1, label = "Polarity")
plt.xlabel("Date")
x2 = x1.twinx()
dtt["AAPL.Close"].plot(ax=x2, label="APPL.Close", color="green")
plt.show()
