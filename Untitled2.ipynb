# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoGuerrero1/Proyecto_EIII/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Método para limpiar el texto y realizar el sentiment analysis
# 1. Importamos nuestras librerias

# %%
import tweepy
from textblob import TextBlob
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt 
plt.style.use('fivethirtyeight')

# %% [markdown]
# 2. Importamos nuestra base de datos como un csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e9960452-9a05-433d-8965-07d64c8c60e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9960452-9a05-433d-8965-07d64c8c60e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2019Tweets.csv to 2019Tweets.csv
# {'2019Tweets.csv': b'"","tweet_id","writer","Date","body","comment_num","retweet_num","like_num"\n"1",1080492044206915584,"Sandro_power",2019-01-02,"$AMZN $AAPL $BA  $MA  $SPY  Live stream Tonight  9pm Eastern Standard Time Canada   https://youtube.com/c/PowerTargetTrades\xe2\x80\xa6   I explain why focused adaptive thinking will be key to wining big in the market, Live stream will be a new format all geared  to help those who are serious about success",12,54,64\n"2",1080580559766765568,"Sandro_power",2019-01-02,"$AMZN $SPY $BA $AAPL todays action in the market and how well these stocks are doing is just a great example of what I call focused adjustment expectations based on skill and adapting. To understand more  why we win big with skill come to my live Stream 9pm Eastern Standard Time",6,52,65\n"3",1080582694160007168,"ScottWapnerCNBC",2019-01-02,"Inquiring minds want to know.  Is @jlebenthal buying $AAPL now that it went below his target?",23,4,61\n"4",1080582808693813248,"Reuters",2019-01-02,"Apple shares down 8 percent in extended trade after company cuts guidance $AAPL https://reut.rs/2F4ozrR",6,45,51\n"5",1080582983688613888,"DougKass",2019-01-02,"Lessons/conclusions from $AAPL:* Be skeptical of company buybacks* Don\'t automatically follow the whales (even Warren Buffett\'s Berkshire Hathaway)* Do your own homework* Does anyone believe the S&P 2019 EPS estimates held by the consensus?@realmoney @jimcramer @saraeisen",8,5,56\n"6",1080583992234135552,"WallStCynic",2019-01-02,"Big $TSLA cheerleader thinks $AAPL is \xe2\x80\x9cgoing out of business\xe2\x80\x9d. @CNBCClosingBell",8,1,51\n"7",1080584066599137280,"jedimarkus77",2019-01-02,"Warren on Line 2....  $AAPL",3,5,65\n"8",1080585209492459520,"StockBoardAsset",2019-01-02,"2019 starts out with $AAPL collapse",6,27,131\n"9",1080585872569974784,"jlebenthal",2019-01-02,"Oh man, Scott. Of course I wanted to be right, but not like this. This is going to be a beat-down for $AAPL. This is a look-out-below moment. When it bottoms I will be in. But this is much worse news than I expected. And it is not good for the market overall, either. Ugh.",22,11,70\n"10",1080586002404651008,"CNBCFastMoney",2019-01-02,"Apple tanking after hours after the company lowered its Q1 guidance. Tune in for what CEO Tim Cook just said $AAPL",36,51,126\n"11",1080586095648272384,"DougKass",2019-01-02,"From my 15 Surprises for 2019  $AAPL \xe2\x80\x9cPeak Apple\xe2\x80\x9d actually happens and its shares fall below $125/share  https://realinvestmentadvice.com/kass-my-15-surprises-for-2019/\xe2\x80\xa6@jimcramer @saraeisen @michaelsantoli @cnbcfastmoney @SquawkCNBC @tomkeene @TeamCavuto @carlquintanillaBerkshire has lost $21.5 billion from the peak",13,4,76\n"12",1080586443167277056,"michaellebowitz",2019-01-02,"$AAPL  Is it China? or is it the fact that you haven\'t materially innovated in years, and yet keep raising prices?""Nike scored higher second-quarter profits Thursday, thanks in part to strong sales in China, where the company ...""",25,71,282\n"13",1080587143976837120,"CNBC",2019-01-02,"Apple drops 7% after warning on Q1 results as iPhones and Apple Watch sales disappoint. $AAPL",14,34,68\n"14",1080587194627227648,"The_Real_Fly",2019-01-02,"NOW $AAPL HAS DECLINING YOY NUMBERS AND $115B IN DEBT, THANKS TO IDIOTIC SHARE BUYBACKS",6,10,58\n"15",1080588175389675520,"TheBubbleBubble",2019-01-02,"The FAANG stocks were a disaster waiting to happen. I was always suspicious of that boom. Unfortunately, I believe it\'s going to get so much worse. As I wrote a few months ago:https://forbes.com/sites/jessecolombo/2018/09/05/disaster-is-inevitable-when-americas-stock-market-bubble-bursts/\xe2\x80\xa6 $AAPL $QQQ",7,33,70\n"16",1080588393824899072,"OptionsMike",2019-01-02,"$AAPL from about 3pm today, someone knew...",19,16,98\n"17",1080591511006466048,"DougKass",2019-01-02,"Berkshire Hathaway paid about $145/share for 252 million shares of $AAPL.The shares are trading at $146 now. @cnbcfastmoney @riskreversa ...

# %%
dta = pd.read_csv("/content/2019Tweets.csv")
dta.head()

# %% [markdown]
# Ahora crearemos un subset con nomás las columnas de "Date" y "Body"

# %%
dta2 = dta[["Date", "body"]]

# %%
dta2.head(3)
# Out:
#          Date                                               body
# 0  2019-01-02  $AMZN $AAPL $BA  $MA  $SPY  Live stream Tonigh...
# 1  2019-01-02  $AMZN $SPY $BA $AAPL todays action in the mark...
# 2  2019-01-02  Inquiring minds want to know.  Is @jlebenthal ...

# %% [markdown]
# Ahora que ya leímos la base de datos vamos a crear una función que limpie el texto

# %%
def cleanTwt(twt):
  twt = re.sub('#apple', 'apple', twt)  
  twt = re.sub('#Apple', 'Apple', twt) 
  twt = re.sub('#[A-Za-z0-9]+', '', twt)
  twt = re.sub('\\n', '', twt)
  twt = re.sub('https?:\/\/\S+', '', twt)
  return twt

# %% [markdown]
# Aplicamos la función a nuestro subset a la columna de "body" y creamos una nueva columna con el texto limpio

# %%
dta2['Cleaned_Tweets'] = dta2['body'].apply(cleanTwt)
dta2.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          Date  ...                                     Cleaned_Tweets
# 0  2019-01-02  ...  $AMZN $AAPL $BA  $MA  $SPY  Live stream Tonigh...
# 1  2019-01-02  ...  $AMZN $SPY $BA $AAPL todays action in the mark...
# 2  2019-01-02  ...  Inquiring minds want to know.  Is @jlebenthal ...
#
# [3 rows x 3 columns]

# %% [markdown]
# Creamos un nuevo subset con solo la fecha y el texto limpio

# %%
dta3 = dta2[["Date", "Cleaned_Tweets"]]
dta.head(3)
# Out:
#    Unnamed: 0      tweet_id  ... retweet_num like_num
# 0           1  1.080492e+18  ...          54       64
# 1           2  1.080581e+18  ...          52       65
# 2           3  1.080583e+18  ...           4       61
#
# [3 rows x 8 columns]

# %% [markdown]
# Ahora crearemos las funciones para asignar la polaridad del sentimiento (donde -1 es muy malo y 1 muy bueno) y la subjetividad. Y posteriormente, creamos 2 nuevas columnas con el nuevo puntaje.

# %%
def getSubjectivity(twt):
  return TextBlob(twt).sentiment.subjectivity

def getPolarity(twt):
  return TextBlob(twt).sentiment.polarity

dta3['Subjectivity'] = dta3['Cleaned_Tweets'].apply(getSubjectivity)
dta3['Polarity'] = dta3['Cleaned_Tweets'].apply(getPolarity)

dta3.head(5)
# Out:
#          Date  ...  Polarity
# 0  2019-01-02  ...  0.046970
# 1  2019-01-02  ...  0.333766
# 2  2019-01-02  ...  0.000000
# 3  2019-01-02  ... -0.155556
# 4  2019-01-02  ...  0.050000
#
# [5 rows x 4 columns]

# %% [markdown]
# Ahora crearemos una función para asignar un sentimiento a los tweets. Donde si la polaridad es >0 es negativo, = 0 es neutro y <0 es positivo.

# %%
def getSentiment(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'

# %% [markdown]
# Posteriormente creamos una nueva columna con el sentimiento de cada tweet.

# %%
dta3['Sentiment'] = dta3['Polarity'].apply(getSentiment)
dta3.head(5)
# Out:
#          Date  ... Sentiment
# 0  2019-01-02  ...  Positive
# 1  2019-01-02  ...  Positive
# 2  2019-01-02  ...   Neutral
# 3  2019-01-02  ...  Negative
# 4  2019-01-02  ...  Positive
#
# [5 rows x 5 columns]
